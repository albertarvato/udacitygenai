# %%
# install requirements.txt
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: torchvision in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 2)) (0.23.0)
# Requirement already satisfied: transformers in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 3)) (4.55.0)
# Requirement already satisfied: diffusers in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 4)) (0.34.0)
# Requirement already satisfied: gradio in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 5)) (5.42.0)
# Requirement already satisfied: Pillow in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 6)) (11.0.0)
# Requirement already satisfied: filelock in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from torch->-r requirements.txt (line 1)) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from torch->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.5)
# Requirement already satisfied: jinja2 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from torch->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from torch->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from torch->-r requirements.txt (line 1)) (80.9.0)
# Requirement already satisfied: numpy in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from torchvision->-r requirements.txt (line 2)) (2.3.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from transformers->-r requirements.txt (line 3)) (0.34.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\conta\appdata\roaming\python\python313\site-packages (from transformers->-r requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from transformers->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from transformers->-r requirements.txt (line 3)) (2025.7.34)
# Requirement already satisfied: requests in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from transformers->-r requirements.txt (line 3)) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from transformers->-r requirements.txt (line 3)) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from transformers->-r requirements.txt (line 3)) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from transformers->-r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: importlib_metadata in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from diffusers->-r requirements.txt (line 4)) (8.7.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (4.10.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.116.1)
# Requirement already satisfied: ffmpy in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: gradio-client==1.11.1 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (1.11.1)
# Requirement already satisfied: groovy~=0.1 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (3.11.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (2.3.1)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (2.11.7)
# Requirement already satisfied: pydub in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.12.8)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.47.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 5)) (0.35.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from gradio-client==1.11.1->gradio->-r requirements.txt (line 5)) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 5)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: certifi in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 5)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\conta\appdata\roaming\python\python313\site-packages (from pandas<3.0,>=1.0->gradio->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from pandas<3.0,>=1.0->gradio->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from pandas<3.0,>=1.0->gradio->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 5)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 5)) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 5)) (14.1.0)
# Requirement already satisfied: colorama in c:\users\conta\appdata\roaming\python\python313\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\conta\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\conta\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 5)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from importlib_metadata->diffusers->-r requirements.txt (line 4)) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers->-r requirements.txt (line 3)) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\conta\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers->-r requirements.txt (line 3)) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# In this project we will build a nice web app that allows you to swap out the background of a subject and substitute it with an image generated by Stable Diffusion through a text prompt:
#
# ![image.png](attachment:image.png)
#
# Let's start by importing what we need:

# %%
from PIL import Image
import requests
from transformers import SamModel, SamProcessor
from diffusers import DiffusionPipeline, AutoPipelineForText2Image, AutoPipelineForInpainting
from diffusers.utils import load_image, make_image_grid

import torch
import numpy as np

# %% [markdown]
# ## SAM
#
# Complete the following cell by loading the pretrained SAM from Facebook/Meta. Remember to:
#
# 1. Move the model to the GPU by adding `.to("cuda")`
# 2. Add the option `torch_dtype=torch.float16` to your call of AutoPipelineForInpainting.from_pretrained
#
# This cell might take a couple of minutes to load.

# %%
# Load the SAM model as we have seen in the class
# Remember to load it on the GPU by adding .to("cuda") if available
model_name = 'facebook/sam-vit-base'
if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"
model = SamModel.from_pretrained(model_name).to(device)
# Load the SamProcessor using the facebook/sam-vit-base
processor = SamProcessor.from_pretrained(model_name)
# checkpoint

# %% [markdown]
# ### Get the mask
#
# Now that you have loaded SAM, complete the following function that uses SAM to produce a segmentation mask:

# %%
def mask_to_rgb(mask):
    """
    Transforms a binary mask into an RGBA image for visualization
    """
    # Ensure mask is boolean
    mask = mask.astype(bool)
    bg_transparent = np.zeros(mask.shape + (4, ), dtype=np.uint8)
    # Color the area we will replace in green
    bg_transparent[mask] = [0, 255, 0, 127]
    bg_transparent[~mask] = [255, 255, 255, 127]
    return bg_transparent

def get_processed_inputs(image, input_points):
    if torch.cuda.is_available():
        device = "cuda"
    elif torch.backends.mps.is_available():
        device = "mps"
    else:
        device = "cpu"
    # Run processor and ensure all tensors are float32 before moving to device
    inputs = processor(image, input_points=input_points, return_tensors="pt")
    for k, v in inputs.items():
        if isinstance(v, torch.Tensor) and v.dtype == torch.float64:
            inputs[k] = v.to(torch.float32)
    inputs = {k: (v.to(device) if isinstance(v, torch.Tensor) else v) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
    masks = processor.image_processor.post_process_masks(
        outputs.pred_masks.cpu(),
        inputs["original_sizes"].cpu(),
        inputs["reshaped_input_sizes"].cpu()
    )
    best_mask = masks[0][0][outputs.iou_scores.argmax()]
    # Return boolean mask for safe inversion
    return (~best_mask.cpu()).bool().numpy()

# %%
# Safely invert a float mask for visualization or processing
def invert_mask(mask):
    # Convert mask to boolean, invert, then back to float32 if needed
    return (~(mask > 0.5)).astype(np.float32)

# %% [markdown]
# Now let's test what we have done so far. By executing this cell you should get a visualization of the mask for the following car:
#
# <img src='car.png' width="200px"></img>
#
# Let's see what happens in this cell:
# 1. We open the image of the car and **we resize it to 512 by 512 pixels** (a square image). This makes things simpler for this project
# 2. We define a few points on the image that indicate where the car is
# 3. We use the function we have defined to generate a mask using SAM
# 4. We visualize the mask
#
# The mask should look like this:
#
# ![image-2.png](attachment:image-2.png)
#
# If it doesn't or you get errors, double check the code you have completed above and fix it before moving on.

# %%
raw_image = Image.open("car.png").convert("RGB").resize((512, 512))

# These are the coordinates of two points on the car
input_points = [[[150, 170], [300, 250]]]

mask = get_processed_inputs(raw_image, input_points)

Image.fromarray(mask_to_rgb(mask)).resize((128, 128))
# Out:
# <PIL.Image.Image image mode=RGBA size=128x128>

# %% [markdown]
# ## Inpainting
#
# Now that we have completed the SAM setup, let's move to the inpainting setup.
#
# Let's start by loading our inpainting pipeline. We will use the `diffusers/stable-diffusion-xl-1.0-inpainting-0.1` pretrained model and the `AutoPipelineForInpainting` as we have seen in our `diffusers` demo in Lesson 5.
#
# Complete the following code and run it (it might take a few minutes to run):
#
# > **NOTE**: you will probably see a warning similar to ``The config attributes {'decay'...``. Please ignore it. It is a warning generated by the diffusers library that does not constitute a problem for our application

# %%
# Load the AutoPipelineForInpainting pipeline 
# (remember the diffusers demo in lesson 5)
# The checkpoint we want to use is 
# "diffusers/stable-diffusion-xl-1.0-inpainting-0.1"

if torch.backends.mps.is_available():
    device = "mps"
    dtype = torch.float32
elif torch.cuda.is_available():
    device = "cuda"
    dtype = torch.float16
else:
    device = "cpu"
    dtype = torch.float32

diffuser_inpaint_model_name = "diffusers/stable-diffusion-xl-1.0-inpainting-0.1"
pipeline = AutoPipelineForInpainting.from_pretrained(diffuser_inpaint_model_name, torch_dtype=dtype)

# Efficient hardware usage
if device == "cuda":
    pipeline.enable_model_cpu_offload()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]The config attributes {'decay': 0.9999, 'inv_gamma': 1.0, 'min_decay': 0.0, 'optimization_step': 37000, 'power': 0.6666666666666666, 'update_after_step': 0, 'use_ema_warmup': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 15.22it/s]

# %% [markdown]
# Now complete the following function that gets in input:
# 1. The raw image
# 2. The mask generated by SAM (a numpy array)
# 3. The text prompt for the infill
# 4. An optional negative prompt
# 5. An optional seed for repeatibility
# 6. The Classifier-Free Guidance Scale (CFGS). If you don't remember what this is, refer to the Text Conditioning explanation in Lesson 5

# %%
def inpaint(raw_image, input_mask, prompt, negative_prompt=None, seed=74294536, cfgs=7):
    mask_image = Image.fromarray(input_mask)
    rand_gen = torch.manual_seed(seed)

    # Use the pipeline we have created in the previous cell
    # Use "prompt" as prompt, 
    # "negative_prompt" as the negative prompt,
    # raw_image as the image,
    # mask_image as the mask_image,
    # rand_gen as the generator and
    # cfgs as the guidance_scale
    image = pipeline(
        prompt=prompt,
        negative_prompt=negative_prompt,
        image=raw_image,
        mask_image=mask_image,
        generator=rand_gen,
        guidance_scale=cfgs,
    ).images[0]
    return image

# %% [markdown]
# Let's test our inpainting on the mask we have obtained earlier with SAM:

# %%
raw_image = raw_image.resize((512, 512))
if isinstance(mask, np.ndarray):
    # If mask is numpy array, convert to PIL and resize, then back to numpy
    mask_img = Image.fromarray(mask).resize((512, 512))
    mask = np.array(mask_img)
elif isinstance(mask, Image.Image):
    mask = mask.resize((512, 512))

# %%
prompt = "a car driving on Mars. Studio lights, 1970s"
negative_prompt = "artifacts, low quality, distortion"

image = inpaint(raw_image, mask, prompt, negative_prompt)
# Out:
# 100%|██████████| 49/49 [17:31<00:00, 21.46s/it]

# %% [markdown]
# Let's have a look at what we have produced:

# %%
fig = make_image_grid([raw_image, Image.fromarray(mask_to_rgb(mask)), image.resize((512, 512))], rows=1, cols=3)
fig
# Out:
# <PIL.Image.Image image mode=RGB size=1536x512>

# %% [markdown]
# ## Interactive app
#
# To make things a bit more fun, we have prepared an interactive app for you that uses the code you have completed and allow you to upload an image, run SAM, and generate the new background through a text prompt.
#
# Simply execute the following cell. The output will contain a preview of the app: **DO NOT USE IT**. Instead, you will also see a link similar to this:
#
# ![image.png](attachment:image.png)
#
# Click on the second link (the public URL), from there you will be able to use the app much more comfortably.
#
# > NOTE: if for any reason you need to stop the app, click on the stop icon of the jupyter interface: ![image-3.png](attachment:image-3.png)  then **execute the next cell containing the code `my_app.close`**

# %%
import app

# %%
my_app = app.generate_app(get_processed_inputs, inpaint)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://829e658228c03ea75f.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://829e658228c03ea75f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 100%|██████████| 49/49 [17:47<00:00, 21.78s/it]

# %%
my_app.close()
